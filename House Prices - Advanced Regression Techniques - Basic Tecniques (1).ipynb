# %% [markdown]
# ### Import relevant libraries
#
# At this point, we are going to import the relevant libraries to run all the code we need for this project.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import seaborn as sns
# Set the styles to Seaborn
sns.set()
# Import the KMeans module so we can perform k-means clustering with sklearn
from sklearn.cluster import KMeans

# %% [markdown]
# ### Load the data
#
# Download the train file containing the data needed for this project.

# %%
df_data = pd.read_csv('sample_submission.csv')

# %%
df_data

# %%
df_data['Id'].head()

# %%
df_data['SalePrice'].head()

# %%
plt.scatter(df['SalePrice'],df['Id'])

plt.xlabel('SalePrice')
plt.ylabel('Id')

# %%
sns.distplot(df['SalePrice'])

# %%
s1 = df['SalePrice'].skew()
k1 = df['SalePrice'].kurt()
print(s1)
print(k1)

# %%
df = pd.read_csv('train.csv')

# %%
df

# %%
df.columns

# %%
df['Id'].describe()

# %% [markdown]
# ### Analysing 'SalePrice'
#
# 'SalePrice' is the reason for our search. We want to understand how the 'SalePrice' variant varies with the following variants:
# * Characteristics of the 'OverallQual' building
#
# * Space of the property 'TotalBsmtSF'
#
# * Location of the property 'Neighborhood'

# %%
df['SalePrice'].describe()

# %%
sns.distplot(df['SalePrice']);

# %% [markdown]
# ### Plot the datas

# %% [markdown]
# #### 1) Create a preliminary plot to see if we can spot SalePrice with OverallQual

# %%
# We are creating a scatter plot of the two variables
plt.scatter(df['OverallQual'],df['SalePrice'])
# Name your axes 
plt.xlabel('OverallQual')
plt.ylabel('SalePrice')

# %% [markdown]
# #### 2) Create a preliminary plot to see if we can spot SalePrice with TotalBsSF

# %%
plt.scatter(df['TotalBsmtSF'],df['SalePrice'])

plt.xlabel('TotalBsmtSF')
plt.ylabel('SalePrice')

# %% [markdown]
# #### 3) Create a preliminary plot to see if we can spot SalePrice with Neighborhood

# %%
plt.scatter(df['Neighborhood'],df['SalePrice'])

plt.xlabel('Neighborhood')
plt.ylabel('SalePrice')

# %%
plt.scatter(df['GrLivArea'],df['SalePrice'])

plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')

# %%
plt.scatter(df['GrLivArea'], df['OverallQual'], c= df ['SalePrice'], cmap = 'rainbow')

# %% [markdown]
# ### In short:
# 'GrLivArea' and 'TotalBsmtSF' align with 'SalePrice'. This means that when one of these variables increases, the other increases as well. In the case of TotalBsmtSF' the slope is high.

# %% [markdown]
# ### Relation between SalePrice and YearBuilt

# %%
plt.scatter(df['YearBuilt'],df['SalePrice'])

plt.xlabel('YearBuilt')
plt.ylabel('SalePrice')

# %%
sns.distplot(df['YearBuilt'])
